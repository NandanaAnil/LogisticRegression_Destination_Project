# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
destination = pd.read_csv('greendestination (1) (1).csv')
destination
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
destination.head(60)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
destination.tail(60)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1410   40        No      Travel_Rarely        444                   Sales
# 1411   25        No      Travel_Rarely        309         Human Resources
# 1412   30        No      Travel_Rarely        911  Research & Development
# 1413   25        No      Travel_Rarely        977  Research & Development
# 1414   47        No      Travel_Rarely       1180  Research & Development
# 1415   33        No         Non-Travel       1313  Research & Development
# 1416   38        No      Travel_Rarely       1321                   Sales
# 1417   31        No      Travel_Rarely       1154                   Sales
# 1418   38        No  Travel_Frequently        508  Research & Development
# 1419   42        No      Travel_Rarely        557  Research & Development
# 1420   41        No      Travel_Rarely        642  Research & Development
# 1421   47        No         Non-Travel       1162  Research & Development
# ...

# %%
destination.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
destination.shape
# Out:
# (1470, 35)

# %%
destination.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
null_values = destination.isnull().sum()
null_values = null_values[null_values>0]
print(null_values)
# Out:
# Series([], dtype: int64)

# %%
destination.select_dtypes(include='object')
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
destination['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
destination.replace({'Attrition':{'No':0, 'Yes':1}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\927597007.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'Attrition':{'No':0, 'Yes':1}}, inplace = True)

# %%
destination['Attrition'].value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
destination['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
destination.replace({'BusinessTravel':{'Travel_Rarely':0, 'Travel_Frequently':1, 'Non-Travel':2}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\3459282216.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'BusinessTravel':{'Travel_Rarely':0, 'Travel_Frequently':1, 'Non-Travel':2}}, inplace = True)

# %%
destination['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# 0    1043
# 1     277
# 2     150
# Name: count, dtype: int64

# %%
destination['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
destination.replace({'Department':{'Research & Development':0, 'Sales':1, 'Human Resources':2}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\3246577395.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'Department':{'Research & Development':0, 'Sales':1, 'Human Resources':2}}, inplace = True)

# %%
destination['Department'].value_counts()
# Out:
# Department
# 0    961
# 1    446
# 2     63
# Name: count, dtype: int64

# %%
destination['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
destination.replace({'EducationField':{'Life Sciences':0, 'Medical':1, 'Marketing':2, 'Technical Degree':3, 'Other':4, 'Human Resources':5}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\4199229965.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'EducationField':{'Life Sciences':0, 'Medical':1, 'Marketing':2, 'Technical Degree':3, 'Other':4, 'Human Resources':5}}, inplace = True)

# %%
destination['EducationField'].value_counts()
# Out:
# EducationField
# 0    606
# 1    464
# 2    159
# 3    132
# 4     82
# 5     27
# Name: count, dtype: int64

# %%
destination['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
destination.replace({'Gender':{'Male':0, 'Female':1}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\1677940855.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'Gender':{'Male':0, 'Female':1}}, inplace = True)

# %%
destination['Gender'].value_counts()
# Out:
# Gender
# 0    882
# 1    588
# Name: count, dtype: int64

# %%
destination['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
destination.replace({'JobRole':{'Sales Executive':0, 'Research Scientist':1, 'Laboratory Technician':2, 'Manufacturing Director':3, 'Healthcare Representative':4, 'Manager':5, 'Sales Representative':6, 'Research Director':7, 'Human Resources':8}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\4045528971.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'JobRole':{'Sales Executive':0, 'Research Scientist':1, 'Laboratory Technician':2, 'Manufacturing Director':3, 'Healthcare Representative':4, 'Manager':5, 'Sales Representative':6, 'Research Director':7, 'Human Resources':8}}, inplace = True)

# %%
destination['JobRole'].value_counts()
# Out:
# JobRole
# 0    326
# 1    292
# 2    259
# 3    145
# 4    131
# 5    102
# 6     83
# 7     80
# 8     52
# Name: count, dtype: int64

# %%
destination['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
destination.replace({'MaritalStatus':{'Married':0, 'Single':1, 'Divorced':2}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\2622021905.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'MaritalStatus':{'Married':0, 'Single':1, 'Divorced':2}}, inplace = True)

# %%
destination['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# 0    673
# 1    470
# 2    327
# Name: count, dtype: int64

# %%
destination['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
destination.replace({'Over18':{'Y':0}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\9672.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'Over18':{'Y':0}}, inplace = True)

# %%
destination['Over18'].value_counts()
# Out:
# Over18
# 0    1470
# Name: count, dtype: int64

# %%
destination['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
destination.replace({'OverTime':{'No':0, 'Yes':1}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\2657220083.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   destination.replace({'OverTime':{'No':0, 'Yes':1}}, inplace = True)

# %%
destination['OverTime'].value_counts()
# Out:
# OverTime
# 0    1054
# 1     416
# Name: count, dtype: int64

# %%
#Plotting
plt.figure(figsize=(10,5))
sns.barplot(x='JobRole', y='MonthlyIncome', data=destination, palette='mako')
plt.title('Income of each job role')
plt.xlabel('Job Role')
plt.ylabel('Income')
plt.show
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\2010071048.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='JobRole', y='MonthlyIncome', data=destination, palette='mako')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Department', y='PerformanceRating', data=destination, palette='flare')
plt.title('Performance Rating of each department')
plt.xlabel('Department')
plt.ylabel('Performance Rating')
plt.show
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\3805608351.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Department', y='PerformanceRating', data=destination, palette='flare')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='DistanceFromHome', y='TotalWorkingYears', data=destination, palette='crest')
plt.title('Total working hours v/s Distance from home')
plt.xlabel('Distance from Home')
plt.ylabel('Total working hours')
plt.show
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10412\3606578754.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='DistanceFromHome', y='TotalWorkingYears', data=destination, palette='crest')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(figsize=(20,20))
sns.boxplot(data = destination, ax=ax)
# Out:
# <Axes: >

# %%
# Exclude 'Attrition' column from outlier detection
numeric_cols = destination.select_dtypes(include=['number']).columns.drop('Attrition')

Q1 = destination[numeric_cols].quantile(0.25)
Q3 = destination[numeric_cols].quantile(0.75)

#Calculate IQR - Inter Quartile Range 
IQR = Q3 - Q1

#Determine the outlier boundaries 
lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR

#Create a mask for data within the IQR boundaries 
mask = ~((destination[numeric_cols] < lower_bound) | (destination[numeric_cols] > upper_bound)).any(axis=1)

#Remove outliers 
cleaned_data = destination[mask]

# %%
# Plotting cleaned_data
fig,ax = plt.subplots(figsize=(20,20))
sns.boxplot(cleaned_data,ax=ax)
# Out:
# <Axes: >

# %%
destination.shape
# Out:
# (1470, 35)

# %%
cleaned_data.shape
# Out:
# (779, 35)

# %%
cleaned_data['Attrition'].value_counts()
# Out:
# Attrition
# 0    641
# 1    138
# Name: count, dtype: int64

# %%
# Listing each feature of the dataframe
print(cleaned_data.columns.tolist())
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
cleaned_data = cleaned_data.drop('EmployeeCount', axis=1)

# %%
cleaned_data = cleaned_data.drop('Over18', axis=1)

# %%
cleaned_data = cleaned_data.drop('StandardHours', axis=1)

# %%
cleaned_data['PerformanceRating'].value_counts()
# Out:
# PerformanceRating
# 3    779
# Name: count, dtype: int64

# %%
cleaned_data = cleaned_data.drop('PerformanceRating', axis=1)

# %%
# Correlation
correlation = cleaned_data.corr()
correlation
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.171781       -0.003007   0.034746
# Attrition                -0.171781   1.000000       -0.004073  -0.057675
# BusinessTravel           -0.003007  -0.004073        1.000000   0.043189
# DailyRate                 0.034746  -0.057675        0.043189   1.000000
# Department               -0.009152   0.071632        0.024870  -0.032150
# DistanceFromHome          0.042349   0.075613        0.019300  -0.019792
# Education                 0.233423  -0.045979        0.010639  -0.052777
# EducationField           -0.060648   0.049218        0.005968  -0.013261
# EmployeeNumber            0.010363   0.002388        0.031721  -0.040787
# EnvironmentSatisfaction   0.004516  -0.116592       -0.012567   0.086427
# Gender                    0.042506  -0.014442       -0.026235  -0.004365
# HourlyRate                0.024751   0.011265        0.010363   0.006573
# ...

# %%
# Heatmap
sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':8}, cmap='viridis')
# Out:
# <Axes: >

# %%
cleaned_data['Attrition'].value_counts()
# Out:
# Attrition
# 0    641
# 1    138
# Name: count, dtype: int64

# %%
x = cleaned_data.drop('Attrition', axis=1)
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 2      37               0       1373           0                 2          2
# 3      33               1       1392           0                 3          4
# 5      32               1       1005           0                 2          2
# 9      36               0       1299           0                27          3
# 11     29               0        153           0                15          2
# ...   ...             ...        ...         ...               ...        ...
# 1463   31               2        325           0                 5          3
# 1464   26               0       1167           1                 5          3
# 1465   36               1        884           0                23          2
# 1468   49               1       1023           1                 2          3
# 1469   34               0        628           0                 8          3
#
# ...

# %%
y = cleaned_data['Attrition']
y
# Out:
# 2       1
# 3       0
# 5       0
# 9       0
# 11      0
#        ..
# 1463    0
# 1464    0
# 1465    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 779, dtype: int64

# %%
# SMOTE - Synthetic Minority Oversampling Techniques
# Smote is a method used in machine learningto address class imbalance in datasets. 
from imblearn.over_sampling import SMOTE

smote = SMOTE()
x_resampled, y_resampled = smote.fit_resample(x,y)

# %%
x_resampled.shape
# Out:
# (1282, 30)

# %%
x.shape
# Out:
# (779, 30)

# %%
y_resampled.shape
# Out:
# (1282,)

# %%
y.shape
# Out:
# (779,)

# %%
# Assigning variables for training and testing
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

# %%
# Checking shape
x_resampled.shape, x_train.shape, x_test.shape, y_resampled.shape, y_test.shape, y_train.shape
# Out:
# ((1282, 30), (897, 30), (385, 30), (1282,), (385,), (897,))

# %%
# Model assigning
model = LogisticRegression()

# %%
# Model fitting
model.fit(x_train,y_train)
# Out:
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Prediction
train_data_predict = model.predict(x_train)
train_data_accuracy = accuracy_score(train_data_predict,y_train)
print('Accuracy of training data',train_data_accuracy)
# Out:
# Accuracy of training data 0.6544035674470458

# %%
test_data_predict = model.predict(x_test)
test_data_accuracy = accuracy_score(test_data_predict,y_test)
print('Accuracy of testing data',test_data_accuracy)
# Out:
# Accuracy of testing data 0.6571428571428571

# %%
# Confusion matrix
cm = confusion_matrix(test_data_predict, y_test)
cm
# Out:
# array([[122,  46],
#        [ 86, 131]], dtype=int64)

# %%
sns.heatmap(cm, annot = True, annot_kws = {'size':20}, fmt = '.2f', cmap = 'viridis', square = True,
           xticklabels = ['True Positives','False Negatives'],
           yticklabels = ['False Positives','True Negatives'])
plt.xlabel('Predicted Data')
plt.ylabel('Actual Data')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification Report
print(classification_report(test_data_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65       168
#            1       0.74      0.60      0.66       217
#
#     accuracy                           0.66       385
#    macro avg       0.66      0.66      0.66       385
# weighted avg       0.67      0.66      0.66       385

# %%
input_data = (37,0,1373,0,2,2,4,4,4,0,92,2,1,2,3,1,2090,2396,6,1,15,2,0,7,3,3,0,0,0,0)    
input_data_as_np = np.asarray(input_data)
input_data_reshaped = input_data_as_np.reshape(1,-1)
prediction = model.predict(input_data_reshaped)
if prediction[0]==0:
    print('Employee is still working in the company')
else: 
    print('Employee left')
# Out:
# Employee is still working in the company
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("Prediction raw output:", prediction)
print("Input shape:", input_data_reshaped.shape)
input_data = (33,1,1392,0,3,4,0,5,4,1,56,3,1,1,3,0,2909,23159,1,1,11,3,0,8,3,3,8,7,3,0)    
input_data_as_np = np.asarray(input_data)
input_data_reshaped = input_data_as_np.reshape(1,-1)
prediction = model.predict(input_data_reshaped)
if prediction[0]==0:
    print('Employee is still working in the company')
else: 
    print('Employee left')
# Out:
# Prediction raw output: [0]
# Input shape: (1, 30)
# Employee is still working in the company
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("Prediction raw output:", prediction)
print("Input shape:", input_data_reshaped.shape)
input_data = (32,1,1005,0,2,2,0,8,4,0,79,3,1,2,4,1,3068,11864,0,0,13,3,0,8,2,2,7,7,3,6)   
input_data_as_np = np.asarray(input_data)
input_data_reshaped = input_data_as_np.reshape(1,-1)
prediction = model.predict(input_data_reshaped)
if prediction[0]==0:
    print('Employee is still working in the company')
else: 
    print('Employee left')
# Out:
# Prediction raw output: [0]
# Input shape: (1, 30)
# Employee is still working in the company
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Count employees who left
employees_left = cleaned_data[cleaned_data['Attrition'] == 1].shape[0]

# Total employees
total_employees = cleaned_data.shape[0]

# Attrition Rate (%)
attrition_rate = (employees_left / total_employees) * 100
print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 17.72%
